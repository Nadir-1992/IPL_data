# %%
import pandas as pd
pd.read_csv('ipl.csv')
data_frame = pd.read_csv('ipl.csv')
data_frame
# Out:
#     First Name   Surname  Reserve Price (Rs. Lakh)      Country  Age  \
# 0       Mayank   Agarwal                       100        India   32
# 1       Piyush    Chawla                        50        India   34
# 2        Kedar    Jadhav                       100        India   38
# 3       Dhawal  Kulkarni                        50        India   34
# 4       Mayank  Markande                        50        India   25
# ..         ...       ...                       ...          ...  ...
# 986  Nicholson    Gordon                        20  West Indies   31
# 987     Kennar     Lewis                        40  West Indies   31
# 988      Ramon  Simmonds                        20  West Indies   21
# 989     Shamar  Springer                        20  West Indies   25
# 990      Nyeem     Young                        30  West Indies   22
#
#             Role   Test caps  ODI caps  T20 caps players    IPL  \
# 0         BATSMAN       21.0       5.0               NaN  113.0
# ...

# %%
import seaborn as sb
import pandas as pd
pd.read_csv('ipl.csv')
data_frame = pd.read_csv('ipl.csv')
sb.set()

graph = sb.scatterplot(x='T20 caps players',y='IPL',data = data_frame)
graph
# Out:
# <Axes: xlabel='T20 caps players', ylabel='IPL'>

# %%
from bokeh.plotting import figure,show
from bokeh.models import HoverTool
import seaborn as sb
import pandas as pd
pd.read_csv('ipl.csv')
data_frame = pd.read_csv('ipl.csv')
sb.set()

graph = sb.scatterplot(x='T20 caps players',y='IPL',data = data_frame)
graph

TOOLTIPS = HoverTool(tooltips=[
    ("index", "$index"),
    ("(Role,IPL)", "(@Role, @IPL)"),
    ("First Name", "@First Name"),
])

# create a new plot with a title and axis labels
p = figure(title="IPL vs INTERNATIONAL", x_axis_label='Age', y_axis_label='IPL',plot_width = 700, plot_height= 700,tools=[TOOLTIPS])
p.circle('T20 caps','IPL',size = 12,source= data_frame)
show(p)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 9
#       6 data_frame = pd.read_csv('ipl.csv')
#       7 sb.set()
# ----> 9 graph = sb.scatterplot(x='T20 caps',y='IPL',data = data_frame)
#      10 graph
#      12 TOOLTIPS = HoverTool(tooltips=[
#      13     ("index", "$index"),
#      14     ("(Role,IPL)", "(@Role, @IPL)"),
#      15     ("First Name", "@First Name"),
#      16 ])
#
# File ~\anaconda3\lib\site-packages\seaborn\relational.py:742, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     732 def scatterplot(
#     733     data=None, *,
#     734     x=None, y=None, hue=None, size=None, style=None,
#    (...)
#     738     **kwargs
#     739 ):
#     741     variables = _ScatterPlotter.get_semantics(locals())
# ...
